# %% [markdown]
# # Use Python on the Backend of HTML

# %%
"""Fills in an HTML template with user data to construct a custom webpage."""

# Collect user profile data.
first_name = input("What's your first name? ")
last_name = input("What's your last name? ")
email = input("Enter your email address: ")
bio = input("Enter a short bio: ")

# Construct a personalized page header for the logged in user.
header_title = "<h1>Profile of "+ first_name +" "+ last_name+"</h1>"
header_subtitle = "<h2>Hello, " + first_name + "!</h2>"
header_content = f'<p><a href="mailto:{email}">"Send an email!"</a></p>'
page_header = header_title + header_subtitle + header_content

# Construct the main profile page content.
section_title = "<h2>About "+first_name+"</h2>"
section_text = "<p>"+bio+"</p>"
button = "<button>Like</button>"
section_footer = "<p>Notifications: 4</p>"
page_content = section_title + section_text + button + section_footer

# The final HTML body combines all the elements, in order.
print("The HTML string for your profile page is:")
print(page_header + page_content)
# Out:
# The HTML string for your profile page is:
# ...

# %% [markdown]
# # Input for the bio section
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Sed augue lacus, vestibulum fermentum viverra vitae, pharetra nec urna. Mauris tincidunt, mauris quis sodales imperdiet, mi purus malesuada justo, eu bibendum tellus odio eu nulla. Pellentesque hendrerit accumsan maximus. Maecenas leo erat, imperdiet a turpis semper, commodo rhoncus tellus. Quisque blandit augue nec elementum fringilla. In ullamcorper, purus non suscipit hendrerit, mi sem pharetra ex, quis pretium enim mauris id turpis. Interdum et malesuada fames ac ante ipsum primis in faucibus. Vivamus pulvinar lectus a mollis vulputate. Sed in sapien lobortis, ultricies turpis eu, iaculis tortor. Fusce sollicitudin tellus ut rutrum elementum. Quisque aliquam ut leo ut ornare. Fusce iaculis dapibus malesuada. Cras eu tellus risus. Fusce viverra dui quam. Nulla ac augue nec mauris congue vulputate.

# %%
from IPython.display import display, HTML

# Use the already constructed HTML string from your variables
display(HTML(page_header + page_content))
# Out:
# <h1>Profile of Bob Smith</h1><h2>Hello, Bob!</h2><p><a href="mailto:bob@email.x">"Send Bob an email!"</a></p><h2>About Bob</h2><p>Lorem ipsum dolor sit amet, consectetur adipiscing elit. Sed augue lacus, vestibulum fermentum viverra vitae, pharetra nec urna. Mauris tincidunt, mauris quis sodales imperdiet, mi purus malesuada justo, eu bibendum tellus odio eu nulla. Pellentesque hendrerit accumsan maximus. Maecenas leo erat, imperdiet a turpis semper, commodo rhoncus tellus. Quisque blandit augue nec elementum fringilla. In ullamcorper, purus non suscipit hendrerit, mi sem pharetra ex, quis pretium enim mauris id turpis. Interdum et malesuada fames ac ante ipsum primis in faucibus. Vivamus pulvinar lectus a mollis vulputate. Sed in sapien lobortis, ultricies turpis eu, iaculis tortor. Fusce sollicitudin tellus ut rutrum elementum. Quisque aliquam ut leo ut ornare. Fusce iaculis dapibus malesuada. Cras eu tellus risus. Fusce viverra dui quam. Nulla ac augue nec mauris congue vulputate.
# ...
